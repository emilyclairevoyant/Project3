# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

# %%
proj_data = pd.read_csv("C:\\Users\\pinkd\\OneDrive\\Desktop\\Project3Stuff\\Resources\\Project3_Data.csv")
proj_data.head()
# Out:
#   Country Name Country Code  \
# 0    Argentina          ARG
# 1    Argentina          ARG
# 2    Argentina          ARG
# 3    Argentina          ARG
# 4    Argentina          ARG
#
#                                          Series Name            Series Code  \
# 0            Access to electricity (% of population)         EG.ELC.ACCS.ZS
# 1  Account ownership at a financial institution o...         FX.OWN.TOTL.ZS
# 2  Adequacy of social protection and labor progra...  per_allsp.adq_pop_tot
# 3                  Air transport, passengers carried            IS.AIR.PSGR
# 4            Compensation of employees (current LCU)         GC.XPN.COMP.CN
#
#   2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018]  \
# 0           100          99.7          99.9           100           100
# 1          50.2            ..            ..         48.71            ..
# 2   38.58560335            ..   37.84584176   39.68798911    38.7727308
# ...

# %%
proj_df= pd.DataFrame(proj_data)
proj_df.head()
# Out:
#   Country Name Country Code  \
# 0    Argentina          ARG
# 1    Argentina          ARG
# 2    Argentina          ARG
# 3    Argentina          ARG
# 4    Argentina          ARG
#
#                                          Series Name            Series Code  \
# 0            Access to electricity (% of population)         EG.ELC.ACCS.ZS
# 1  Account ownership at a financial institution o...         FX.OWN.TOTL.ZS
# 2  Adequacy of social protection and labor progra...  per_allsp.adq_pop_tot
# 3                  Air transport, passengers carried            IS.AIR.PSGR
# 4            Compensation of employees (current LCU)         GC.XPN.COMP.CN
#
#   2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018]  \
# 0           100          99.7          99.9           100           100
# 1          50.2            ..            ..         48.71            ..
# 2   38.58560335            ..   37.84584176   39.68798911    38.7727308
# ...

# %%
proj_df.drop('Series Code', axis=1, inplace=True)
proj_df.head()
# Out:
#   Country Name Country Code  \
# 0    Argentina          ARG
# 1    Argentina          ARG
# 2    Argentina          ARG
# 3    Argentina          ARG
# 4    Argentina          ARG
#
#                                          Series Name 2014 [YR2014]  \
# 0            Access to electricity (% of population)           100
# 1  Account ownership at a financial institution o...          50.2
# 2  Adequacy of social protection and labor progra...   38.58560335
# 3                  Air transport, passengers carried   12121912.82
# 4            Compensation of employees (current LCU)   1.38384E+11
#
#   2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019]  \
# 0          99.7          99.9           100           100           100
# 1            ..            ..         48.71            ..            ..
# 2            ..   37.84584176   39.68798911    38.7727308   39.04418575
# 3      14245183      15076354      16749271      18084553      19461377
# ...

# %%
proj_df.drop(columns=['2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'], axis=1, inplace=True)

# %%
proj_df.rename(columns={'2019 [YR2019]':'2019', 
                        '2020 [YR2020]': '2020', 
                        '2021 [YR2021]': '2021', 
                        '2022 [YR2022]': '2022', 
                        '2023 [YR2023]': '2023'},
              inplace=True)

# %%
proj_df.head()
# Out:
#   Country Name Country Code  \
# 0    Argentina          ARG
# 1    Argentina          ARG
# 2    Argentina          ARG
# 3    Argentina          ARG
# 4    Argentina          ARG
#
#                                          Series Name         2019  \
# 0            Access to electricity (% of population)          100
# 1  Account ownership at a financial institution o...           ..
# 2  Adequacy of social protection and labor progra...  39.04418575
# 3                  Air transport, passengers carried     19461377
# 4            Compensation of employees (current LCU)  5.31295E+11
#
#           2020         2021        2022 2023
# 0          100          100         100   ..
# 1           ..        71.63          ..   ..
# 2  39.30133787  36.56051927          ..   ..
# 3      3680874      6708097          ..   ..
# 4  6.83039E+11   1.0684E+12  1.9792E+12   ..

# %% [markdown]
# ***
# ### Developed Countries (based on United Nations classifications):
# Austria, Belgium, Denmark, Finland, France, Germany, Greece, Ireland, Italy
# Luxembourg, Netherlands, Portugal, Spain, Sweden, United Kingdom, Bulgaria, Croatia, Cyprus, Czech Republic, Estonia, Hungary, Latvia,
# Lithuania, Malta, Poland, Romania, Slovakia, Slovenia, Iceland, Norway, Switzerland, Australia, Canada, Japan, New Zealand, United Statesatesd
# ###
# ***
# Economies in Trans
# Albania, Bosnia and Herzegovina, Montenegro, Serbia, The former Yugoslav Republic of Macedonia, Armenia, Azerbaijan, Belarus, Georgiaa, Kazakhstan, Kyrgyzstan, Republic of Moldova, Russian Federation, Tajikistan, Turkmenistan, Ukraine, Uzbekistan
# ***
#
# ### Developing Countries
# Algeria, Egypt, Libyab, Mauritania, Morocco, Sudan, Tunisia, Cameroon, Central African Republic, Chad, Congo, Equatorial Guinea, Gabon, Sao Tome and Prinicipe, Burundi, Comoros, Democratic Republic of the Congo, Djibouti, Eritrea, Ethiopia, Kenya, Madagascar, Rwanda, Somalia, Uganda, United Republic
# of Tanzania, Angola, Botswana, Lesotho, Malawi, Mauritius, Mozambique, Namibia, South Africa, Zambia, Zimbabwe, Benin, Burkina Faso, Cabo Verde, Côte d’Ivoire, Gambia, Ghana, Guinea, Guinea-Bissau, Liberia, Mali, Niger, Nigeria, Senegal, Sierra Leone, Togo, Brunei Darussalam, China (because of the economic disparity between different groups), Hong Kong SARc, Indonesia, Malaysia, Myanmar, Papua New Guinea, Philippines, Republic of Korea, Singapore, Taiwan Province of China, Thailand, Viet Nam, Bangladesh, India, Iran (Islamic Republic of), Nepal, Pakistan, Sri Lanka, Bahrain, Iraq, Israel, Jordan, Kuwait, Lebanon, Oman, Qatar, Saudi Arabia, Syrian Arab Repuplic, Turkey, United Arab Emirates, Yemen, Barbados, Cuba, Dominican Republic, Guyana, Haiti, Jamaica, Trinidad and Tobago, Costa Rica, El Salvador, Guatemala, Honduras, Mexico, Nicaragua, Panama, Argentina, Bolivia (Plurinational State of), Brazil, Chile, Colombia, Ecuador, Paraguay, Peru, Uruguay, Venezuela (Bolivarian Republic of)epublic of)PanamaTobagorates
# YemenLankand
# Viet Nam
# ra Leone
# Togora Leone
# Togo
# Zimbabwe
# of Tanzanianicipeunisiaistanzstanblicition

# %%
immunization_group=proj_df[proj_df['Series Name'].isin(['Immunization, DPT (% of children ages 12-23 months)', 'Immunization, HepB3 (% of one-year-old children)', 'Immunization, measles (% of children ages 12-23 months)'])].groupby('Series Name')

# %%
immunization_group.head()
# Out:
#     Country Name Country Code  \
# 16     Argentina          ARG
# 17     Argentina          ARG
# 18     Argentina          ARG
# 80     Australia          AUS
# 81     Australia          AUS
# 82     Australia          AUS
# 144       Brazil          BRA
# 145       Brazil          BRA
# 146       Brazil          BRA
# 208        China          CHN
# 209        China          CHN
# 210        China          CHN
# 272       France          FRA
# 273       France          FRA
# 274       France          FRA
#
#                                            Series Name 2019 2020 2021 2022  \
# 16   Immunization, DPT (% of children ages 12-23 mo...   83   74   81   81
# 17    Immunization, HepB3 (% of one-year-old children)   83   74   81   81
# 18   Immunization, measles (% of children ages 12-2...   86   77   86   83
# 80   Immunization, DPT (% of children ages 12-23 mo...   95   95   95   94
# 81    Immunization, HepB3 (% of one-year-old children)   95   95   95   94
# ...

# %%
developed_countries = [
    'Austria', 'Belgium', 'Denmark', 'Finland', 'France', 'Germany', 'Greece', 
    'Ireland', 'Italy', 'Luxembourg', 'Netherlands', 'Portugal', 'Spain', 
    'Sweden', 'United Kingdom', 'Bulgaria', 'Croatia', 'Cyprus', 
    'Czech Republic', 'Estonia', 'Hungary', 'Latvia', 'Lithuania', 
    'Malta', 'Poland', 'Romania', 'Slovakia', 'Slovenia', 'Iceland', 
    'Norway', 'Switzerland', 'Australia', 'Canada', 'Japan', 
    'New Zealand', 'United States'
]


immunization_series = [
    'Immunization, DPT (% of children ages 12-23 months)', 
    'Immunization, HepB3 (% of one-year-old children)', 
    'Immunization, measles (% of children ages 12-23 months)'
]


proj_df_developed = proj_df[proj_df['Country Name'].isin(developed_countries)]


immunization_group = proj_df_developed[proj_df_developed['Series Name'].isin(immunization_series)]


sorted_immunization = immunization_group.sort_values(by='Country Name')


sorted_immunization.head()
# Out:
#      Country Name Country Code  \
# 80      Australia          AUS
# 81      Australia          AUS
# 82      Australia          AUS
# 1874      Austria          AUT
# 1873      Austria          AUT
#
#                                             Series Name 2019 2020 2021 2022  \
# 80    Immunization, DPT (% of children ages 12-23 mo...   95   95   95   94
# 81     Immunization, HepB3 (% of one-year-old children)   95   95   95   94
# 82    Immunization, measles (% of children ages 12-2...   94   93   93   96
# 1874  Immunization, measles (% of children ages 12-2...   95   95   99   95
# 1873   Immunization, HepB3 (% of one-year-old children)   85   85   86   84
#
#      2023
# 80     ..
# 81     ..
# 82     ..
# 1874   ..
# 1873   ..

# %%
sorted_immunization_2019 = sorted_immunization[sorted_immunization['2019'].notnull()]


sorted_immunization_2019 = sorted_immunization_2019[['Country Name', 'Country Code', 'Series Name', '2019']]

sorted_immunization_2019.head()
# Out:
#      Country Name Country Code  \
# 80      Australia          AUS
# 81      Australia          AUS
# 82      Australia          AUS
# 1874      Austria          AUT
# 1873      Austria          AUT
#
#                                             Series Name 2019
# 80    Immunization, DPT (% of children ages 12-23 mo...   95
# 81     Immunization, HepB3 (% of one-year-old children)   95
# 82    Immunization, measles (% of children ages 12-2...   94
# 1874  Immunization, measles (% of children ages 12-2...   95
# 1873   Immunization, HepB3 (% of one-year-old children)   85

# %%
developed_countries = [
    'Austria', 'Belgium', 'Denmark', 'Finland', 'France', 'Germany', 'Greece', 
    'Ireland', 'Italy', 'Luxembourg', 'Netherlands', 'Portugal', 'Spain', 
    'Sweden', 'United Kingdom', 'Bulgaria', 'Croatia', 'Cyprus', 
    'Czech Republic', 'Estonia', 'Hungary', 'Latvia', 'Lithuania', 
    'Malta', 'Poland', 'Romania', 'Slovakia', 'Slovenia', 'Iceland', 
    'Norway', 'Switzerland', 'Australia', 'Canada', 'Japan', 
    'New Zealand', 'United States'
]


unique_proj_df = proj_df.drop_duplicates(subset=['Country Name', 'Series Name'])


filtered_proj_df = unique_proj_df[unique_proj_df['Country Name'].isin(developed_countries)]


pivot_df = filtered_proj_df.pivot(index='Country Name', columns='Series Name', values='2019').reset_index()


for col in immunization_columns:
    pivot_df[col] = pd.to_numeric(pivot_df[col], errors='coerce')


sorted_immunization_2019 = pivot_df.sort_values(by='Country Name')


immunization_columns = [
    'Immunization, measles (% of children ages 12-23 months)',
    'Immunization, HepB3 (% of one-year-old children)',
    'Immunization, DPT (% of children ages 12-23 months)'
]


fig, ax = plt.subplots(figsize=(12, 10))


left = [0] * len(sorted_immunization_2019)


for col, color, label in zip(immunization_columns, ["slategray", "palevioletred", "peachpuff"], ["Measles", "HepB3", "DPT"]):
    ax.barh(sorted_immunization_2019['Country Name'], 
            sorted_immunization_2019[col], 
            left=left, 
            color=color, 
            label=label)
   
    left = [i+j for i,j in zip(left, sorted_immunization_2019[col])]


ax.set_xlabel("% of Immunized Population")
ax.set_ylabel("Country")
ax.set_title("% of Immunized Population for Developed Nations, 2019")
ax.legend()


plt.tight_layout()
plt.show()
