# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# Take in all of our consolidated data and read it into pandas
consolidated  = "..\Resources/consolidated_WQI_data.csv"
consolidated_df = pd.read_csv(consolidated )

# %%
# Display all column names in the consolidated_WQI_data DataFrame
print(consolidated_df.columns.tolist())
# Out:
# ['Country Name', 'Country Code', 'Access to electricity (% of population)_2018', 'Adequacy of social protection and labor programs (% of total welfare of beneficiary households)_2018', 'Air transport, passengers carried_2018', 'Compensation of employees (current LCU)_2018', 'Contraceptive prevalence, any method (% of married women ages 15-49)_2018', 'Control of Corruption: Estimate_2018', 'Cost of business start-up procedures (% of GNI per capita)_2018', 'Current education expenditure, total (% of total expenditure in public institutions)_2018', 'Current health expenditure (% of GDP)_2018', 'Forest area (% of land area)_2018', 'Gini index_2018', 'Government Effectiveness: Estimate_2018', 'Hospital beds (per 1,000 people)_2018', 'Human capital index (HCI) (scale 0-1)_2018', 'Immunization, DPT (% of children ages 12-23 months)_2018', 'Immunization, HepB3 (% of one-year-old children)_2018', 'Immunization, measles (% of children ages 12-23 months)_2018', 'Individuals using the Internet (
# ...

# %%
# Filter to keep only the specified columns for healthcare
health_columns = [
    'Country Name', 
    'Country Code', 
    'Immunization, DPT (% of children ages 12-23 months)_2018', 
    'Immunization, DPT (% of children ages 12-23 months)_2019', 
    'Immunization, DPT (% of children ages 12-23 months)_2020', 
    'Immunization, DPT (% of children ages 12-23 months)_2021', 
    'Immunization, DPT (% of children ages 12-23 months)_2022', 
    'Current health expenditure (% of GDP)_2018', 
    'Current health expenditure (% of GDP)_2019', 
    'Current health expenditure (% of GDP)_2020', 
    'Current health expenditure (% of GDP)_2021', 
    'Current health expenditure (% of GDP)_2022', 
    'Out-of-pocket expenditure (% of current health expenditure)_2018', 
    'Out-of-pocket expenditure (% of current health expenditure)_2019', 
    'Out-of-pocket expenditure (% of current health expenditure)_2020', 
    'Out-of-pocket expenditure (% of current health expenditure)_2021', 
    'Out-of-pocket expenditure (% of current health expenditure)_2022', 
    'Immunization, measles (% of children ages 12-23 months)_2018', 
    'Immunization, measles (% of children ages 12-23 months)_2019', 
    'Immunization, measles (% of children ages 12-23 months)_2020', 
    'Immunization, measles (% of children ages 12-23 months)_2021', 
    'Immunization, measles (% of children ages 12-23 months)_2022', 
    'Life expectancy at birth, total (years)_2018', 
    'Life expectancy at birth, total (years)_2019', 
    'Life expectancy at birth, total (years)_2020', 
    'Life expectancy at birth, total (years)_2021', 
    'Life expectancy at birth, total (years)_2022', 
    'Survival to age 65, male (% of cohort)_2018', 
    'Survival to age 65, male (% of cohort)_2019', 
    'Survival to age 65, male (% of cohort)_2020', 
    'Survival to age 65, male (% of cohort)_2021', 
    'Survival to age 65, male (% of cohort)_2022', 
    'Survival to age 65, female (% of cohort)_2018', 
    'Survival to age 65, female (% of cohort)_2019', 
    'Survival to age 65, female (% of cohort)_2020', 
    'Survival to age 65, female (% of cohort)_2021', 
    'Survival to age 65, female (% of cohort)_2022'
]

# %%
# Create the heralth DataFrame
health = consolidated_df[health_columns]
health.head()
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND
#
#    Immunization, DPT (% of children ages 12-23 months)_2018  \
# 0                                               72.0
# 1                                               99.0
# 2                                               91.0
# 3                                               95.0
# 4                                               99.0
#
#    Immunization, DPT (% of children ages 12-23 months)_2019  \
# 0                                               72.0
# 1                                               99.0
# 2                                               88.0
# 3                                               93.5
# 4                                               99.0
#
#    Immunization, DPT (% of children ages 12-23 months)_2020  \
# ...

# %%
# Save the consolidated DataFrame to a CSV file
health.to_csv('..\Resources/health.csv', index=False)
