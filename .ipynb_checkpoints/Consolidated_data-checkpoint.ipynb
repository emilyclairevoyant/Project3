# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# Take in all of our WQI data and read it into pandas
WQI_2018 = "Resources/2018_data.csv"
WQI_2019 = "Resources/2019_data.csv"
WQI_2020 = "Resources/2020_data.csv"
WQI_2021 = "Resources/2021_data.csv"
WQI_2022 = "Resources/2022_data.csv"


WQI_2018_df = pd.read_csv(WQI_2018)
WQI_2019_df = pd.read_csv(WQI_2019)
WQI_2020_df = pd.read_csv(WQI_2020)
WQI_2021_df = pd.read_csv(WQI_2021)
WQI_2022_df = pd.read_csv(WQI_2022)

# %%
# Rename columns to include the year
WQI_2018_df = WQI_2018_df.rename(columns=lambda x: f"{x}_2018")
WQI_2019_df = WQI_2019_df.rename(columns=lambda x: f"{x}_2019")
WQI_2020_df = WQI_2020_df.rename(columns=lambda x: f"{x}_2020")
WQI_2021_df = WQI_2021_df.rename(columns=lambda x: f"{x}_2021")
WQI_2022_df = WQI_2022_df.rename(columns=lambda x: f"{x}_2022")

# %%
# Merge the DataFrames on Country Name column
consolidated_WQI_df = WQI_2018_df.merge(WQI_2019_df, left_on='Country Name_2018', right_on='Country Name_2019', how='outer') \
                                   .merge(WQI_2020_df, left_on='Country Name_2018', right_on='Country Name_2020', how='outer') \
                                   .merge(WQI_2021_df, left_on='Country Name_2018', right_on='Country Name_2021', how='outer') \
                                   .merge(WQI_2022_df, left_on='Country Name_2018', right_on='Country Name_2022', how='outer')
consolidated_WQI_df.head()
# Out:
#   Country Name_2018 Country Code_2018  \
# 0       Afghanistan               AFG
# 1           Albania               ALB
# 2           Algeria               DZA
# 3    American Samoa               ASM
# 4           Andorra               AND
#
#    Access to electricity (% of population)_2018  \
# 0                                          93.4
# 1                                         100.0
# 2                                          99.6
# 3                                          99.8
# 4                                         100.0
#
#    Adequacy of social protection and labor programs (% of total welfare of beneficiary households)_2018  \
# 0                                                NaN
# 1                                         296.540585
# 2                                         235.347075
# 3                                         174.153564
# 4                                         112.960054
#
#    Air transport, passengers carried_2018  \
# ...

# %%
# Rename the columns back to their original names
consolidated_WQI_df.rename(columns={
    'Country Name_2018': 'Country Name',
    'Country Code_2018': 'Country Code'},inplace = True)
consolidated_WQI_df.head()
# Out:
#      Country Name Country Code  Access to electricity (% of population)_2018  \
# 0     Afghanistan          AFG                                          93.4
# 1         Albania          ALB                                         100.0
# 2         Algeria          DZA                                          99.6
# 3  American Samoa          ASM                                          99.8
# 4         Andorra          AND                                         100.0
#
#    Adequacy of social protection and labor programs (% of total welfare of beneficiary households)_2018  \
# 0                                                NaN
# 1                                         296.540585
# 2                                         235.347075
# 3                                         174.153564
# 4                                         112.960054
#
#    Air transport, passengers carried_2018  \
# 0                               1125367.0
# 1                                303137.0
# ...

# %%
# Handle null values
consolidated_WQI_df.fillna('',inplace=True)
consolidated_WQI_df.head()
# Out:
# C:\Users\ambmd\AppData\Local\Temp\ipykernel_30392\394682919.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   consolidated_WQI_df.fillna('',inplace=True)
#      Country Name Country Code  Access to electricity (% of population)_2018  \
# 0     Afghanistan          AFG                                          93.4
# 1         Albania          ALB                                         100.0
# 2         Algeria          DZA                                          99.6
# 3  American Samoa          ASM                                          99.8
# 4         Andorra          AND                                         100.0
#
#   Adequacy of social protection and labor programs (% of total welfare of beneficiary households)_2018  \
# 0
# 1                                         296.540585
# ...

# %%
#drop unnnecessary columns 
columns_to_drop = ['Country Name_2019', 'Country Code_2019','Country Name_2020', 'Country Code_2020', 'Country Name_2021', 'Country Code_2021', 'Country Name_2022', 'Country Code_2022']

# Drop the specified columns
# Drop the specified columns and assign the result to a new DataFrame
consolidated_WQI_data = consolidated_WQI_df.drop(columns=columns_to_drop, errors='ignore')
print(consolidated_WQI_data.head())
# Out:
#      Country Name Country Code  Access to electricity (% of population)_2018  \
# 0     Afghanistan          AFG                                          93.4
# 1         Albania          ALB                                         100.0
# 2         Algeria          DZA                                          99.6
# 3  American Samoa          ASM                                          99.8
# 4         Andorra          AND                                         100.0
#
#   Adequacy of social protection and labor programs (% of total welfare of beneficiary households)_2018  \
# 0
# 1                                         296.540585
# 2                                         235.347075
# 3                                         174.153564
# 4                                         112.960054
#
#    Air transport, passengers carried_2018  \
# 0                               1125367.0
# 1                                303137.0
# 2                               6442442.0
# ...

# %%
# Save the consolidated DataFrame to a CSV file
consolidated_WQI_data.to_csv('Resources/consolidated_WQI_data.csv', index=False)

# %%
# Display all column names in the consolidated_WQI_data DataFrame
print(consolidated_WQI_data.columns.tolist())
# Out:
# ['Country Name', 'Country Code', 'Access to electricity (% of population)_2018', 'Adequacy of social protection and labor programs (% of total welfare of beneficiary households)_2018', 'Air transport, passengers carried_2018', 'Compensation of employees (current LCU)_2018', 'Contraceptive prevalence, any method (% of married women ages 15-49)_2018', 'Control of Corruption: Estimate_2018', 'Cost of business start-up procedures (% of GNI per capita)_2018', 'Current education expenditure, total (% of total expenditure in public institutions)_2018', 'Current health expenditure (% of GDP)_2018', 'Forest area (% of land area)_2018', 'Gini index_2018', 'Government Effectiveness: Estimate_2018', 'Hospital beds (per 1,000 people)_2018', 'Human capital index (HCI) (scale 0-1)_2018', 'Immunization, DPT (% of children ages 12-23 months)_2018', 'Immunization, HepB3 (% of one-year-old children)_2018', 'Immunization, measles (% of children ages 12-23 months)_2018', 'Individuals using the Internet (
# ...

# %%
# Filter to keep only the specified columns for peace and security
peace_and_security_columns = [
    'Country Name', 
    'Country Code', 
    'Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)_2018',
    'Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)_2019',
    'Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)_2020',
    'Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)_2021',
    'Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)_2022',
    'Political Stability and Absence of Violence/Terrorism: Estimate_2018',
    'Political Stability and Absence of Violence/Terrorism: Estimate_2019',
    'Political Stability and Absence of Violence/Terrorism: Estimate_2020',
    'Political Stability and Absence of Violence/Terrorism: Estimate_2021',
    'Political Stability and Absence of Violence/Terrorism: Estimate_2022',
    'Rule of Law: Estimate_2018', 
    'Rule of Law: Estimate_2019',
    'Rule of Law: Estimate_2020',
    'Rule of Law: Estimate_2021',
    'Rule of Law: Estimate_2022',
    'Internally displaced persons, total displaced by conflict and violence (number of people)_2018',
    'Internally displaced persons, total displaced by conflict and violence (number of people)_2019',
    'Internally displaced persons, total displaced by conflict and violence (number of people)_2020',
    'Internally displaced persons, total displaced by conflict and violence (number of people)_2021',
    'Internally displaced persons, total displaced by conflict and violence (number of people)_2022',    
    'Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)_2018',
    'Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)_2019',
    'Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)_2020',
    'Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)_2021',
    'Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)_2022',    
    'Refugee population by country or territory of asylum_2018',
    'Refugee population by country or territory of asylum_2019',
    'Refugee population by country or territory of asylum_2020',
    'Refugee population by country or territory of asylum_2021',
    'Refugee population by country or territory of asylum_2022',
    'Voice and Accountability: Estimate_2018', 
    'Voice and Accountability: Estimate_2019',
    'Voice and Accountability: Estimate_2020',
    'Voice and Accountability: Estimate_2021',
    'Voice and Accountability: Estimate_2022',
    'Control of Corruption: Estimate_2018',
    'Control of Corruption: Estimate_2019',
    'Control of Corruption: Estimate_2020',
    'Control of Corruption: Estimate_2021',
    'Control of Corruption: Estimate_2022',
    'Losses due to theft and vandalism (% of annual sales for affected firms)_2018', 
    'Losses due to theft and vandalism (% of annual sales for affected firms)_2019', 
    'Losses due to theft and vandalism (% of annual sales for affected firms)_2020', 
    'Losses due to theft and vandalism (% of annual sales for affected firms)_2021', 
    'Losses due to theft and vandalism (% of annual sales for affected firms)_2022', 
    'Government Effectiveness: Estimate_2018', 
    'Government Effectiveness: Estimate_2019', 
    'Government Effectiveness: Estimate_2020', 
    'Government Effectiveness: Estimate_2021', 
    'Government Effectiveness: Estimate_2022', 
    'Proportion of seats held by women in national parliaments (%)_2018', 
    'Proportion of seats held by women in national parliaments (%)_2019', 
    'Proportion of seats held by women in national parliaments (%)_2020', 
    'Proportion of seats held by women in national parliaments (%)_2021', 
    'Proportion of seats held by women in national parliaments (%)_2022', 
    'Net migration_2018', 
    'Net migration_2019', 
    'Net migration_2020', 
    'Net migration_2021', 
    'Net migration_2022'
]

# %%
# Create the peace and security DataFrame
peace_and_security = consolidated_WQI_data[peace_and_security_columns]
peace_and_security.head()
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1         Albania          ALB
# 2         Algeria          DZA
# 3  American Samoa          ASM
# 4         Andorra          AND
#
#   Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)_2018  \
# 0
# 1                                               61.9
# 2                                          63.792308
# 3                                          65.684615
# 4                                          67.576923
#
#   Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)_2019  \
# 0
# 1
# 2
# 3
# 4
#
#   Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care (% of women age 15-49)_2020  \
# 0
# 1
# 2
# 3
# 4
#
# ...

# %%
peace_and_security.shape
# Out:
# (218, 62)

# %%
# Save the consolidated DataFrame to a CSV file
peace_and_security.to_csv('Resources/Peace_and_Security.csv', index=False)

# %%
# Take in all of our WQI data and read it into pandas
Population = "Resources\API_SP.POP.TOTL_DS2_en_csv_v2_31753.csv"
Quality_of_Life = "Resources\standard-of-living-by-country-_-quality-of-life-by-country-2024.csv"

Population_df = pd.read_csv(Population)
Quality_of_Life_df = pd.read_csv(Quality_of_Life)

Population_df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2014         2015         2016         2017  \
# ...

# %%
#Replace the column name in the Quality_of_life_df
Quality_of_Life_df.rename(columns={
    'country': 'Country Name'
   },inplace = True)
Quality_of_Life_df.head()
# Out:
#     Country Name  StandardOfLiving_QoLScoreNumbeo_2024MidYear  \
# 0          India                                        123.8
# 1          China                                        116.4
# 2  United States                                        185.1
# 3      Indonesia                                         98.6
# 4       Pakistan                                        104.5
#
#    StandardOfLiving_QoLScoreUSNews_2023  \
# 0                                  19.0
# 1                                  76.1
# 2                                  49.1
# 3                                  20.0
# 4                                   NaN
#
#    StandardOfLiving_QoLScoreCEOWorld_2024  StandardOfLiving_HDIScoreUN_2022  \
# 0                                   60.81                             0.644
# 1                                   77.97                             0.788
# 2                                   96.65                             0.927
# ...

# %%
# Filter to keep only the specified columns for QoL Scores
QoL_columns = [
    'Country Name','StandardOfLiving_QoLScoreNumbeo_2023MidYear']
# Create the QoL Scores Data Frame
QoL_scores = Quality_of_Life_df[QoL_columns]
# create a new column with heading as Rank and find the Ranks based on the QoL score values 
# The highest quality index gets rank 1
QoL_scores.loc[:, 'Rank'] = QoL_scores['StandardOfLiving_QoLScoreNumbeo_2023MidYear'].rank(ascending=False)
#Replace the column name in the QoL_scores
QoL_scores.rename(columns={
    'StandardOfLiving_QoLScoreNumbeo_2023MidYear': 'Quality of Life (Numbeo 2023) '
   },inplace = True)
QoL_scores.head()
# Out:
# C:\Users\ambmd\AppData\Local\Temp\ipykernel_30392\655907607.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   QoL_scores.loc[:, 'Rank'] = QoL_scores['StandardOfLiving_QoLScoreNumbeo_2023MidYear'].rank(ascending=False)
# C:\Users\ambmd\AppData\Local\Temp\ipykernel_30392\655907607.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   QoL_scores.rename(columns={
#     Country Name  Quality of Life (Numbeo 2023)   Rank
# 0          India                           116.1  55.0
# 1          China                           105.1  64.0
# ...

# %%
# Filter to keep only the specified columns for population
Population_columns = [
    'Country Name','Country Code','2023']
# Create the Demographics Data Frame
Demographics_df = Population_df[Population_columns]
#Replace the column name in the Demographics_df
Demographics_df.rename(columns={
    '2023': 'Population'
   },inplace = True)
Demographics_df.head()
# Out:
# C:\Users\ambmd\AppData\Local\Temp\ipykernel_30392\482065974.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Demographics_df.rename(columns={
#                   Country Name Country Code   Population
# 0                        Aruba          ABW     106277.0
# 1  Africa Eastern and Southern          AFE  739108306.0
# 2                  Afghanistan          AFG   42239854.0
# 3   Africa Western and Central          AFW  502789511.0
# 4                       Angola          AGO   36684202.0

# %%
# Merge the DataFrames on Country Name column, including only common country names
Summary_df = Demographics_df.merge(QoL_scores, on='Country Name', how='inner')
Summary_df.head()
# Out:
#            Country Name Country Code  Population  \
# 0           Afghanistan          AFG  42239854.0
# 1                Angola          AGO  36684202.0
# 2               Albania          ALB   2745972.0
# 3               Andorra          AND     80088.0
# 4  United Arab Emirates          ARE   9516871.0
#
#    Quality of Life (Numbeo 2023)   Rank
# 0                             NaN   NaN
# 1                             NaN   NaN
# 2                             NaN   NaN
# 3                             NaN   NaN
# 4                           173.8  15.0

# %%
num_rows = len(Summary_df)  # This also gives you the number of rows
print("Number of rows in Summary_df:", num_rows)
# Out:
# Number of rows in Summary_df: 169

# %%
# Save the summary DataFrame to a CSV file
Summary_df.to_csv('Resources/Summary_Info.csv', index=False)
